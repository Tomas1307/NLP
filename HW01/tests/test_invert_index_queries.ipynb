# %%
from algorithms.binary_search.inverted_index import InvertedIndex
import pandas as pd
import json
import glob
from KafNafParserPy import KafNafParser

# %%
inverted_index = InvertedIndex()

# %%
inverted_index.inverted_index_complete_pipeline(occurrences=True)
# Out:
# 2024-09-04 08:57:07,170 - InvertedIndex - INFO - Starting complete inverted index pipeline
# 2024-09-04 08:57:07,170 - InvertedIndex - INFO - Starting complete inverted index pipeline
# 2024-09-04 08:57:07,171 - InvertedIndex - INFO - Step 1: Processing texts
# 2024-09-04 08:57:07,171 - InvertedIndex - INFO - Step 1: Processing texts
# 2024-09-04 08:57:07,173 - TextProcessor - INFO - Starting text processing pipeline
# 2024-09-04 08:57:07,173 - TextProcessor - INFO - Starting text processing pipeline
# 2024-09-04 08:57:07,173 - TextProcessor - INFO - Reading files from directory: data/docs-raw-texts/
# 2024-09-04 08:57:07,173 - TextProcessor - INFO - Reading files from directory: data/docs-raw-texts/
# 2024-09-04 08:57:07,235 - TextProcessor - INFO - Finished reading files. Time taken: 0.06 seconds
# 2024-09-04 08:57:07,235 - TextProcessor - INFO - Finished reading files. Time taken: 0.06 seconds
# ...

# %%
with open("inverted_index.json") as file:
    inverted_index = json.load(file)
inverted_index
# Out:
# {'(001,1)': ['218'],
#  '(01,1)': ['305'],
#  '(0314,1)': ['098'],
#  '(044,1)': ['099'],
#  '(0511,1)': ['125'],
#  '(06,1)': ['167'],
#  '(085,1)': ['118'],
#  '(10,41)': ['012',
#   '023',
#   '037',
#   '038',
#   '043',
#   '048',
#   '052',
#   '080',
#   '084',
#   '091',
#   '098',
#   '109',
#   '112',
#   '118',
#   '128',
#   '130',
#   '139',
#   '170',
#   '199',
#   '200',
#   '208',
#   '209',
#   '214',
#   '231',
#   '234',
#   '239',
#   '240',
#   '242',
#   '245',
#   '269',
#   '293',
#   '302',
#   '307',
#   '309',
#   '310',
#   '313',
#   '324'],
#  '(100,22)': ['005',
#   '070',
#   '080',
#   '085',
#   '090',
#   '150',
#   '159',
#   '167',
#   '175',
#   '176',
#   '177',
#   '179',
#   '180',
#   '194',
#   '199',
#   '223',
#   '230',
#   '244',
#   '257',
#   '268',
#   '288'],
#  '(1000,14)': ['021',
#   '023',
#   '024',
#   '141',
#   '145',
#   '157',
#   '169',
#   '180',
#   '184',
#   '253',
#   '269',
#   '282'],
# ...

# %%
def read_queries(directory: str = "data/queries-raw-texts/"):
    # Ruta al directorio con los archivos .naf

    # Buscar todos los archivos que coincidan con el patrón
    files = glob.glob(directory + "wes2015.q*.naf")

    # Lista para almacenar los datos
    data = []

    # Procesar cada archivo
    for file in files:
        # Extraer el identificador del nombre del archivo
        identifier = file.split(".")[-2][-3:]  # Extrae '001', '002', etc.
        
        # Crear el objeto KafNafParser para el archivo actual
        naf_parser = KafNafParser(file)
        raw_text = naf_parser.get_raw()
        data.append({"identifier": identifier, "query": raw_text})
    
    return pd.DataFrame(data)

queries_df = read_queries()
queries_df
# Out:
#    identifier                                              query
# 0         q01                   Fabrication of music instruments
# 1         q02                               famous German poetry
# 2         q03                                        Romanticism
# 3         q04                   University of Edinburgh research
# 4         q06                                bridge construction
# 5         q07                                 Walk of Fame stars
# 6         q08           Scientists who worked on the atomic bomb
# 7         q09                          Invention of the Internet
# 8         q10                    early telecommunication methods
# 9         q12                        Who explored the South Pole
# 10        q13                   famous members of the Royal Navy
# 11        q14                     Nobel Prize winning inventions
# 12        q16                                      South America
# ...

# %%
from utils_processor.processor import Processor
import nltk
from nltk import word_tokenize
processor_ = Processor()

# %%
for i in range(len(queries_df["query"])):
    query = queries_df["query"][i]  # Obtén el query actual

    # Verifica si el query es de tipo string
    if not isinstance(query, str):
        print(f"Error en el índice {i}: El tipo de dato es {type(query)}, valor: {query}")
        continue  # Salta este query y continúa con el siguiente

    # Aplica los pasos de preprocesamiento
    try:
        tokens = word_tokenize(query)  # Tokeniza el query en una lista de palabras
        tokens = processor_.to_lowercase(tokens)  # Convierte a minúsculas
        tokens = processor_.remove_punctuation(tokens)  # Elimina la puntuación
        tokens = processor_.remove_non_ascii(tokens)  # Elimina caracteres no ASCII
        tokens = processor_.remove_stopwords(tokens)  # Elimina stopwords
        tokens = processor_.stem_verbs(tokens)  # Aplica stemming a los verbos

        # Une los tokens nuevamente en una cadena de texto y actualiza el DataFrame
        queries_df["query"][i] = ' '.join(tokens)
    except Exception as e:
        print(f"Error en el índice {i} con query: {query}")
        print(f"Mensaje de error: {e}")

queries_df
# Out:
# C:\Users\Rog\AppData\Local\Temp\ipykernel_7720\2708613111.py:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   queries_df["query"][i] = ' '.join(tokens)
#    identifier                                     query
# ...

# %%
queries_df["query_list"] = [0] * 35
for i in range(0,len(queries_df["query"])):
    queries_df["query_list"][i] = queries_df["query"][i].split()
queries_df
# Out:
# C:\Users\Rog\AppData\Local\Temp\ipykernel_7720\1520044997.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   queries_df["query_list"][i] = queries_df["query"][i].split()
# ...

# %%
import pandas as pd
import os
import glob
from KafNafParserPy import KafNafParser
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from utils_processor.processor import Processor
import nltk
from nltk import word_tokenize

# %%
def read_files(directory: str = "data/docs-raw-texts/"):
    # Ruta al directorio con los archivos .naf

    # Buscar todos los archivos que coincidan con el patrón
    files = glob.glob(directory + "wes2015.d*.naf")

    # Lista para almacenar los datos
    data = []

    # Procesar cada archivo
    for file in files:
        # Extraer el identificador del nombre del archivo
        identifier = file.split(".")[-2][-3:]  # Extrae '001', '002', etc.
        
        # Crear el objeto KafNafParser para el archivo actual
        naf_parser = KafNafParser(file)
        
        # Extraer el texto crudo
        raw_text = naf_parser.get_raw()

        title = naf_parser.root.find('nafHeader/fileDesc').get('title')
        
        # Agregar los datos a la lista
        data.append({"identifier": identifier, "text": raw_text, "title":title})

    df = pd.DataFrame(data)
    return df

df = read_files()


def replace_title_on_text(dataFrame):
    for i in range(0,len(dataFrame["text"])):
        if dataFrame["title"][i] in dataFrame["text"][i]:
            dataFrame["text"][i] = dataFrame["text"][i].replace(dataFrame["title"][i]+".","")
        if "\n" in dataFrame["text"][i]:
            dataFrame["text"][i] = dataFrame["text"][i].replace("\n","")


replace_title_on_text(df)



processor_ = Processor()

df["text"] = df["text"]+ " " + df["title"]
df.drop(columns=["title"],inplace=True)
for i in range(0,len(df["text"])):
    df["text"][i] = word_tokenize(df["text"][i])
    df["text"][i] = processor_.to_lowercase(df["text"][i])
    df["text"][i] = processor_.to_lowercase(df["text"][i])
    df["text"][i] = processor_.remove_punctuation(df["text"][i])
    df["text"][i] = processor_.remove_non_ascii(df["text"][i])
    df["text"][i] = processor_.remove_stopwords(df["text"][i])
    df["text"][i] = processor_.stem_verbs(df["text"][i])
    df["text"][i] = ' '.join(df["text"][i])


df["text_list"] = [0] * 331
for i in range(0,len(df["text"])):
    df["text_list"][i] = df["text"][i].split()
df
# Out:
# C:\Users\Rog\AppData\Local\Temp\ipykernel_7720\3801354630.py:35: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataFrame["text"][i] = dataFrame["text"][i].replace(dataFrame["title"][i]+".","")
# ...

# %% [markdown]
# check if all of the token queries are on the inverted index

# %%
for i in range(0,len(df["text_list"])):
    if "world" and "war" in df["text_list"][i]:
        print(df["text"][i])
# Out:
# william beaumont physiolog digest imag sourc novemb 21 1785 usamerican surgeon william beaumont born becam best known father gastric physiolog follow research human digest william beaumont born lebanon connecticut becam physician serv surgeon mate armi war 1812 open privat practic plattsburgh new york rejoin armi surgeon 1819 beaumont station fort mackinac mackinac island michigan earli 1820 exist protect interest american fur compani fort becam refug wound 19yearold frenchcanadian fur trader name alexi st martin shotgun went accid american fur compani store close rang june 6th 1822 st martin wound quit seriou stomach perfor sever rib broken nobodi realli expect young man would surviv realli skin around st martin wound fuse hole stomach leav perman open gastric fistula 1 beaumont quickli notic much research potenti back much known digest system order gain inform beaumont perform numer experi st martin period eight year experi must realli uncomfort man insert bit differ food tie strin
# ...

# %%
# Primero, extraemos las claves de inverted_index
inverted_index_keys = set(inverted_index.keys())

# Inicializamos listas para guardar los términos faltantes
missing_terms_df = []
missing_terms_queries_df = []

# Buscar términos faltantes en df["text"]
for idx, row in df.iterrows():
    text_terms = set(row['text_list'])
    missing_in_text = text_terms - inverted_index_keys
    if missing_in_text:
        missing_terms_df.append({'identifier': row['identifier'], 'missing_terms': list(missing_in_text)})

# Buscar términos faltantes en queries_df["query"]
for idx, row in queries_df.iterrows():
    query_terms = set(row['query_list'])
    missing_in_query = query_terms - inverted_index_keys
    if missing_in_query:
        missing_terms_queries_df.append({'identifier': row['identifier'], 'missing_terms': list(missing_in_query)})

# Convertimos los resultados a DataFrames para visualización
missing_terms_df = pd.DataFrame(missing_terms_df)
missing_terms_queries_df = pd.DataFrame(missing_terms_queries_df)

print("Términos faltantes en df['text']:")
print(missing_terms_df)

print("\nTérminos faltantes en queries_df['query']:")
print(missing_terms_queries_df)
# Out:
# Términos faltantes en df['text']:
#     identifier                                      missing_terms
# 0          001  [rib, experi, age, around, muscl, stomach, hol...
# 1          002  [tini, around, white, regular, literari, focu,...
# 2          003  [held, trial, charg, ten, end, berkeley, famil...
# 3          004  [disney, 1928, found, third, star, whistl, fin...
# 4          005  [goeppertmay, structur, 100, 1958, meet, presi...
# ..         ...                                                ...
# 326        327  [age, structur, basal, found, muscl, melita, m...
# 327        328  [experi, 1928, dissymmetri, without, republica...
# 328        329  [common, age, structur, slow, ton, decad, cons...
# 329        330  [chart, age, 1772, 1793, friend, export, incor...
# 330        331  [guid, found, gold, rather, took, honor, agre,...
#
# [331 rows x 2 columns]
#
# Términos faltantes en queries_df['query']:
#    identifier                                   missing_terms
# ...

# %%
queries_df
# Out:
#    identifier                                             query  \
# 0         q01                      fabrication music instrument
# 1         q02                              famous german poetry
# 2         q03                                       romanticism
# 3         q04                     university edinburgh research
# 4         q06                               bridge construction
# 5         q07                                    walk fame star
# 6         q08                       scientists work atomic bomb
# 7         q09                                invention internet
# 8         q10                   early telecommunication methods
# 9         q12                                explore south pole
# 10        q13                         famous members royal navy
# 11        q14                        nobel prize win inventions
# 12        q16                                     south america
# 13        q17                         edward teller marie curie
# ...

# %%
from algorithms.binary_search.binary_search import BinarySearch

BinarySearch_ = BinarySearch()
output_file = "BSII-AND-queries_result.txt"
BinarySearch_.generate_results_file(queries_df, inverted_index, output_file)

print(f"Archivo de resultados generado: {output_file}")
print(f"Contenido del archivo:")
with open(output_file, 'r') as f:
    print(f.read())
# Out:
# Archivo de resultados generado: BSII-AND-queries_result.txt
# Contenido del archivo:
# q01
# q02 d291,d293
# q03 d105,d147,d152,d283,d291,d318
# q04 d286
# q05 d026,d029,d069,d257,d297,d303,d329
# q06 d004,d034
# q07 d108,d117,d205,d251
# q08 d198,d205,d223
# q09
# q10 d250
# q11
# q12
# q13 d132,d150,d176,d184,d229,d250,d277
# q14 d121,d271
# q15 d192,d194,d203,d210
# q16 d179
# q17
# q18
# q19 d129,d221
# q20 d020,d032,d167
# q21
# q22
# q23 d136,d174
# q24 d037,d046,d294
# q25 d025,d031,d090,d139,d254
# q26
# q27
# q28 d169
# q29
# q30
# q31
# q32
# q33 d029,d185
# q34
# q35 d094,d133

# %%
from algorithms.binary_search.binary_search import BinarySearch

BinarySearch_ = BinarySearch()
# Uso del algoritmo
new_inverted_index_and_method = {}
for i in range(len(queries_df["query_list"])):
    index_values = []
    for j in queries_df["query_list"][i]:
        index_values.append(inverted_index[j])
    new_inverted_index_and_method[queries_df["query"][i]] = index_values

for k, v in new_inverted_index_and_method.items():
    # Asegurarse de que todas las listas estén ordenadas
    sorted_lists = [sorted(sublist) for sublist in v]
    result = BinarySearch_.intersect_multiple_lists(sorted_lists)
    print(f"Query: {k}")
    print(f"Listas originales: {v}")
    print(f"Resultado de la intersección: {result}")
    print(f"Número de documentos en la intersección: {len(result)}")

    queries_df["query"]
# Out:
# Query: fabrication music instrument
# Listas originales: [['085', '170'], ['004', '006', '039', '059', '060', '065', '094', '100', '130', '136', '152', '153', '162', '164', '179', '184', '185', '195', '209', '215', '254', '311', '312', '316'], ['016', '028', '038', '060', '074', '082', '085', '099', '100', '116', '153', '170', '172', '186', '212', '229', '234', '243', '254', '255', '265', '273', '281', '284', '299', '315', '317', '329']]
# Resultado de la intersección: []
# Número de documentos en la intersección: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 21
#      18 print(f"Resultado de la intersección: {result}")
#      19 print(f"Número de documentos en la intersección: {len(result)}")
# ---> 21 queries_df["query"][k]
#
# ...

# %%
# Prueba específica para "fabrication music instrument"
test_query = "fabrication music instrument"
test_lists = [
    ['085', '170'],
    ['004', '006', '039', '059', '060', '065', '094', '100', '130', '136', '152', '153', '162', '164', '179', '184', '185', '195', '209', '215', '254', '311', '312', '316'],
    ['016', '028', '038', '060', '074', '082', '085', '099', '100', '116', '153', '170', '172', '186', '212', '229', '234', '243', '254', '255', '265', '273', '281', '284', '299', '315', '317', '329']
]
test_result = BinarySearch_.intersect_multiple_lists(test_lists)
print(f"Prueba para '{test_query}':")
print(f"Resultado de la intersección: {test_result}")
print(f"Número de documentos en la intersección: {len(test_result)}")
# Out:
# Prueba para 'fabrication music instrument':
# Resultado de la intersección: []
# Número de documentos en la intersección: 0

# %%
test_result
# Out:
# []
