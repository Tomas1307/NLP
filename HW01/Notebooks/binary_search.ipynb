# %% [markdown]
# # Binary Search

# %%
from algorithms.binary_search.inverted_index import InvertedIndex

# %%
inverted_index = InvertedIndex()

# %% [markdown]
# ### Inverted Index

# %% [markdown]
# Decidimos hacer el inverted index con un parametro de ocurrences para saber si es necesario o no (Esto se hizo pensando en acceder de forma mas rapida a los recursos del indice invertido dependienod de si es RRDV o Binary search)

# %%
index = inverted_index.inverted_index_complete_pipeline()
index
# Out:
# 2024-09-04 15:35:54,888 - InvertedIndex - INFO - Starting complete inverted index pipeline
# 2024-09-04 15:35:54,890 - InvertedIndex - INFO - Step 1: Processing texts
# 2024-09-04 15:35:54,890 - TextProcessor - INFO - Starting text processing pipeline
# 2024-09-04 15:35:54,891 - TextProcessor - INFO - Reading files from directory: data/docs-raw-texts/
# 2024-09-04 15:35:57,669 - TextProcessor - INFO - Finished reading files. Time taken: 2.78 seconds
# 2024-09-04 15:35:57,670 - TextProcessor - INFO - Replacing titles in text and cleaning newlines
# C:\Users\Rog\Desktop\Andes\10\Natural Language Processing\NLP\HW01\algorithms\binary_search\text_processor.py:82: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataFrame["text"][i] = dataFrame["text"][i].replace(dataFrame["title"][i] + ".", "")
# C:\Users\Rog\Desktop\Andes\10\Natural Language Processing\NLP\HW01\algorithms\binary_search\text_processor.py:83: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataFrame["text"][i] = dataFrame["text"][i].replace("\n", "")
# 2024-09-04 15:35:57,695 - TextProcessor - INFO - Finished replacing titles. Time taken: 0.02 seconds
# 2024-09-04 15:35:57,695 - TextProcessor - INFO - Processing and normalizing text
# 2024-09-04 15:35:59,770 - TextProcessor - INFO - Completed text processing pipeline. Total time taken: 4.88 seconds
# 2024-09-04 15:35:59,771 - InvertedIndex - INFO - Step 2: Applying vectorizer and processing
# 2024-09-04 15:35:59,772 - InvertedIndex - INFO - Applying vectorizer and processing
# 2024-09-04 15:35:59,857 - InvertedIndex - INFO - Finished vectorization and processing. Time taken: 0.08 seconds
# 2024-09-04 15:35:59,858 - InvertedIndex - INFO - Step 3: Creating inverted index
# 2024-09-04 15:35:59,859 - InvertedIndex - INFO - Creating inverted index
# 2024-09-04 15:36:18,612 - InvertedIndex - INFO - Finished creating inverted index. Time taken: 18.75 seconds
# 2024-09-04 15:36:18,613 - InvertedIndex - INFO - Step 4: Saving inverted index
# 2024-09-04 15:36:18,614 - InvertedIndex - INFO - Saving inverted index to inverted_index_without_ocurrences.json
# 2024-09-04 15:36:18,689 - InvertedIndex - INFO - Inverted index successfully saved to inverted_index_without_ocurrences.json
# 2024-09-04 15:36:18,690 - InvertedIndex - INFO - Completed inverted index pipeline. Total time taken: 23.80 seconds
# {'001': ['218'],
#  '01': ['305'],
#  '0314': ['098'],
#  '044': ['099'],
#  '0511': ['125'],
#  '06': ['167'],
#  '085': ['118'],
#  '10': ['012',
#   '023',
#   '037',
#   '038',
#   '043',
#   '048',
#   '052',
#   '080',
#   '084',
#   '091',
#   '098',
#   '109',
#   '112',
#   '118',
#   '128',
#   '130',
#   '139',
#   '170',
#   '199',
#   '200',
#   '208',
#   '209',
#   '214',
#   '231',
#   '234',
#   '239',
#   '240',
#   '242',
#   '245',
#   '269',
#   '293',
#   '302',
#   '307',
#   '309',
#   '310',
#   '313',
#   '324'],
#  '100': ['005',
#   '070',
#   '080',
#   '085',
#   '090',
#   '150',
#   '159',
#   '167',
#   '175',
#   '176',
#   '177',
#   '179',
#   '180',
#   '194',
#   '199',
#   '223',
#   '230',
#   '244',
#   '257',
#   '268',
#   '288'],
#  '1000': ['021',
#   '023',
#   '024',
#   '141',
#   '145',
#   '157',
#   '169',
#   '180',
#   '184',
#   '253',
#   '269',
#   '282'],
#  '10000': ['040', '116', '150'],
#  '100000': ['115', '116', '204', '240', '258'],
#  '1000volt': ['076'],
#  '100yen': ['204'],
#  '101': ['090', '255'],
#  '102': ['145'],
#  '1024': ['303'],
#  '103': ['098'],
#  '1030': ['199'],
#  '104': ['324'],
#  '105': ['090'],
#  '1057': ['125'],
#  '106': ['080'],
#  '10cm': ['081'],
#  '10foot': ['155'],
#  '10person': ['192'],
#  '10th': ['172'],
#  '11': ['011',
#   '016',
#   '038',
#   '042',
#   '079',
#   '084',
#   '096',
#   '097',
#   '108',
#   '112',
#   '138',
#   '149',
#   '169',
#   '198',
#   '205',
#   '220',
#   '222',
#   '239',
#   '241',
#   '250',
#   '251',
#   '277',
#   '312',
#   '314',
#   '327'],
#  '1100': ['017', '146'],
#  '1100km': ['258'],
#  '1103': ['303'],
#  '11046': ['099'],
#  '111': ['112'],
#  '1120': ['244'],
#  '1122': ['139'],
#  '113': ['090'],
#  '114': ['098', '283'],
#  '114000': ['322'],
#  '1147': ['139'],
#  '115': ['184'],
#  '1152': ['139'],
#  '1156': ['139'],
#  '1158': ['139'],
#  '1159': ['139'],
#  '116': ['011'],
#  '1166': ['139'],
#  '1183': ['139'],
#  '1187': ['139'],
#  '1190': ['139'],
#  '1199': ['017'],
#  '11th': ['169'],
#  '11thcenturi': ['080'],
#  '12': ['008',
#   '009',
#   '010',
#   '013',
#   '014',
#   '017',
#   '019',
#   '020',
#   '022',
#   '032',
#   '035',
#   '038',
#   '041',
#   '044',
#   '051',
#   '056',
#   '058',
#   '059',
#   '062',
#   '065',
#   '066',
#   '070',
#   '071',
#   '075',
#   '077',
#   '078',
#   '081',
#   '082',
#   '086',
#   '089',
#   '097',
#   '107',
#   '126',
#   '134',
#   '137',
#   '143',
#   '146',
#   '149',
#   '165',
#   '168',
#   '175',
#   '184',
#   '192',
#   '193',
#   '195',
#   '216',
#   '226',
#   '236',
#   '239',
#   '240',
#   '246',
#   '253',
#   '255',
#   '259',
#   '261',
#   '270',
#   '272',
#   '278',
#   '282',
#   '289',
#   '290',
#   '292',
#   '296',
#   '302',
#   '307',
#   '312',
#   '315',
#   '320',
#   '325',
#   '329'],
#  '120': ['056', '181', '253'],
#  '1200': ['279'],
#  '12000': ['157'],
#  '1200014000': ['092'],
#  '123': ['071', '195', '278', '284'],
#  '1250m': ['123'],
#  '1252': ['061'],
#  '127000': ['155'],
#  '128': ['182'],
#  '1282': ['080'],
#  '129915': ['098'],
#  '12engin': ['166'],
#  '12inchwid': ['248'],
#  '12th': ['327'],
#  '12thcenturi': ['311'],
#  '12year': ['071'],
#  '13': ['009',
#   '017',
#   '022',
#   '026',
#   '040',
#   '050',
#   '062',
#   '063',
#   '066',
#   '070',
#   '072',
#   '075',
#   '077',
#   '084',
#   '103',
#   '106',
#   '109',
#   '110',
#   '122',
#   '125',
#   '134',
#   '136',
#   '150',
#   '166',
#   '167',
#   '168',
#   '181',
#   '208',
#   '228',
#   '231',
#   '244',
#   '252',
#   '267',
#   '269',
#   '279',
#   '282',
#   '289',
#   '291',
#   '294',
#   '311',
#   '315',
#   '324',
#   '329',
#   '330'],
#  '130': ['147', '157'],
#  '1300': ['169'],
#  '13000': ['090'],
#  '13000000': ['231'],
#  '130pm': ['245'],
#  '131': ['167'],
#  '132': ['323'],
#  '134': ['118', '297'],
#  '136': ['272'],
#  '1360': ['277'],
#  '1394': ['282'],
#  '13th': ['080', '169'],
#  '14': ['008',
#   '010',
#   '023',
#   '056',
#   '057',
#   '071',
#   '076',
#   '089',
#   '098',
#   '105',
#   '135',
#   '155',
#   '166',
#   '167',
#   '185',
#   '186',
#   '212',
#   '224',
#   '227',
#   '231',
#   '240',
#   '241',
#   '253',
#   '255',
#   '261',
#   '264',
#   '287',
#   '308',
#   '309',
#   '310',
#   '315',
#   '323'],
#  '140': ['183', '331'],
#  '1400': ['049', '297'],
#  '140000': ['090'],
#  '14031437': ['055'],
#  '1404': ['163'],
#  '1407': ['282'],
#  '1420': ['282'],
#  '1428': ['282'],
#  '1430': ['128'],
#  '1437': ['282'],
#  '1438': ['163'],
#  '1447': ['282'],
#  '145': ['190'],
#  '1450': ['023'],
#  '1450s': ['169'],
#  '1451': ['169'],
#  '1460s': ['169'],
#  '1476': ['083'],
#  '1477': ['229'],
#  '14771547': ['229'],
#  '1480': ['033'],
#  '1480s': ['167'],
#  '1481': ['176'],
#  '1482': ['244'],
#  '1493': ['132', '176'],
#  '1494': ['083', '229'],
#  '1498': ['229'],
#  '1499': ['229'],
#  '14acr': ['184'],
#  '14th': ['163', '196', '217', '254', '314'],
#  '14year': ['324'],
#  '15': ['007',
#   '016',
#   '019',
#   '029',
#   '037',
#   '038',
#   '048',
#   '052',
#   '063',
#   '068',
#   '075',
#   '078',
#   '091',
#   '093',
#   '104',
#   '123',
#   '134',
#   '137',
#   '157',
#   '165',
#   '183',
#   '188',
#   '190',
#   '195',
#   '199',
#   '201',
#   '207',
#   '214',
#   '230',
#   '231',
#   '237',
#   '254',
#   '261',
#   '263',
#   '282',
#   '286',
#   '289',
#   '296',
#   '309',
#   '322'],
#  '150': ['248', '322', '323'],
#  '1500': ['109', '261'],
#  '15000': ['150'],
#  '150000': ['024'],
#  '1502': ['176'],
#  '1504': ['229'],
#  '1505': ['083'],
#  '1506': ['229'],
#  '1507': ['229'],
#  '1511': ['031'],
#  '1512': ['176'],
#  '1513': ['033', '132', '229'],
#  '1514': ['255'],
#  '1515': ['033', '229'],
#  '1516': ['120', '187'],
#  '15161585': ['120'],
#  '1517': ['033'],
#  '1518': ['176'],
#  '1519': ['261', '324'],
#  '1520': ['229'],
#  '152024': ['025'],
#  '1523': ['033'],
#  '1524': ['033'],
#  '1525': ['229', '261'],
#  '1526': ['033', '229'],
#  '1527': ['324'],
#  '1530': ['031', '033', '120', '324'],
#  '1533': ['229', '255', '324'],
#  '1535': ['031', '120'],
#  '1536': ['031'],
#  '1537': ['049'],
#  '1538': ['033', '229', '255'],
#  '1539': ['229', '255'],
#  '1540': ['033', '132', '229'],
#  '1541': ['229', '255'],
#  '1542': ['132'],
#  '1544': ['229', '324'],
#  '1545': ['229'],
#  '1546': ['083', '120'],
#  '1547': ['160', '261'],
#  '1548': ['120'],
#  '1549': ['031'],
#  '1550': ['232', '255'],
#  '1551': ['031', '255', '261'],
#  '1552': ['120'],
#  '1553': ['031', '083'],
#  '1554': ['120', '261'],
#  '1557': ['120'],
#  '1559': ['311', '324'],
#  '1560': ['232', '324'],
#  '1562': ['027', '324'],
#  '1563': ['311'],
#  '1564': ['160'],
#  '15641647': ['235'],
#  '1566': ['324'],
#  '1568': ['324'],
#  '156km': ['134'],
#  '1570': ['160', '324'],
#  '15701643': ['049'],
#  '1570s': ['132'],
#  '1571': ['160'],
#  '1572': ['234', '324'],
#  '1573': ['160', '234'],
#  '15731625': ['234'],
#  '1574': ['120', '273'],
#  '1575': ['160', '178'],
#  '1577': ['132'],
#  '1578': ['120', '160'],
#  '1579': ['132'],
#  '1580': ['232'],
#  '1581': ['120', '132'],
#  '1582': ['031', '120'],
#  '1583': ['012', '120', '261'],
#  '1584': ['311'],
#  '1585': ['240'],
#  '1588': ['232'],
#  '1592': ['232', '235', '240', '261', '273'],
#  '15921655': ['235'],
#  '1593': ['049'],
#  '1594': ['234'],
#  '1596': ['232', '234'],
#  '1599': ['234'],
#  '15m': ['018', '128'],
#  '15th': ['068', '163', '169', '176'],
#  '16': ['006',
#   '034',
#   '035',
#   '037',
#   '048',
#   '057',
#   '074',
#   '076',
#   '103',
#   '133',
#   '140',
#   '148',
#   '149',
#   '188',
#   '189',
#   '195',
#   '212',
#   '222',
#   '229',
#   '235',
#   '242',
#   '243',
#   '252',
#   '255',
#   '259',
#   '261',
#   '264',
#   '277',
#   '280',
#   '281',
#   '291',
#   '307',
#   '317',
#   '321',
#   '329'],
#  '160': ['067', '132', '303'],
#  '1601': ['234'],
#  '1603': ['261', '273'],
#  '1604': ['178', '234', '303'],
#  '1605': ['178'],
#  '1607': ['098'],
#  '1608': ['038', '234'],
#  '16081647': ['038'],
#  '1609': ['178', '234'],
#  '161': ['184'],
#  '1610': ['112', '234', '273'],
#  '1611': ['234', '243'],
#  '1612': ['234', '235'],
#  '1614': ['234'],
#  '1615': ['240'],
#  '1616': ['035'],
#  '1617': ['235', '240'],
#  '1618': ['171'],
#  '1620': ['012', '099', '241', '273'],
#  '16201683': ['012'],
#  '16211675': ['241'],
#  '1622': ['273'],
#  '1623': ['235'],
#  '1624': ['038', '232', '234', '235', '240'],
#  '163': ['020'],
#  '1630': ['240', '273'],
#  '1631': ['235', '273'],
#  '1632': ['273'],
#  '1637': ['235'],
#  '1638': ['226'],
#  '1639': ['243'],
#  '1640': ['281'],
#  '1640s': ['241'],
#  '1641': ['038', '235'],
#  '1642': ['038', '171', '235', '241'],
#  '1643': ['038'],
#  '1644': ['038'],
#  '1645': ['235'],
#  '1646': ['221', '241', '317'],
#  '1647': ['038', '235', '243'],
#  '1648': ['012', '235', '299'],
#  '1649': ['012'],
#  '1650': ['012', '241'],
#  '1651': ['056'],
#  '1653': ['035', '235'],
#  '1654': ['027'],
#  '16541720': ['027'],
#  '1655': ['099', '235'],
#  '1656': ['241'],
#  '1658': ['232'],
#  '1659': ['241'],
#  '165m': ['287'],
#  '166': ['130'],
#  '1660': ['012', '171', '226', '241', '272', '281'],
#  '1661': ['241'],
#  '1662': ['272'],
#  '1663': ['241'],
#  '1664': ['241', '243', '272'],
#  '1665': ['079', '272'],
#  '1666': ['099', '226', '241'],
#  '1669': ['012', '099', '226'],
#  '1670': ['007', '099', '171', '221'],
#  '1671': ['099', '171', '299'],
#  '16712': ['191'],
#  '1672': ['012', '027', '272', '281'],
#  '1673': ['079', '099', '243', '281', '299'],
#  '16731754': ['079'],
#  '1674': ['241', '295'],
#  '1675': ['226', '241'],
#  '1675m': ['123'],
#  '1676': ['285'],
#  '1677': ['272'],
#  '1678': ['281'],
#  '1679': ['243', '281'],
#  '1680': ['171', '243', '299'],
#  '1681': ['281'],
#  '1682': ['099', '264', '281'],
#  '1683': ['012', '056'],
#  '1684': ['027'],
#  '1685': ['072', '281'],
#  '16851731': ['072'],
#  '1686': ['226'],
#  '1687': ['015', '072', '243', '281', '299'],
#  '1688': ['056', '294'],
#  '16881772': ['294'],
#  '1689': ['007', '027', '317'],
#  '1691': ['007'],
#  '1692': ['079'],
#  '1693': ['295', '317'],
#  '1695': ['079', '299'],
#  '1697': ['056'],
#  '1699': ['056'],
#  '16m': ['276'],
#  '16pin': ['214'],
#  '16th': ['073', '120'],
#  '17': ['003',
#   '005',
#   '023',
#   '026',
#   '073',
#   '084',
#   '088',
#   '092',
#   '098',
#   '103',
#   '109',
#   '132',
#   '157',
#   '167',
#   '170',
#   '181',
#   '196',
#   '213',
#   '218',
#   '232',
#   '250',
#   '256',
#   '270',
#   '289',
#   '295',
#   '301',
#   '320'],
#  '170': ['144'],
#  '1700': ['186', '305'],
#  '1701': ['056', '072', '264', '295'],
#  '1702': ['079', '281'],
#  '1703': ['294'],
#  '170304': ['317'],
#  '1704': ['317'],
#  '1705': ['007', '281'],
#  '1706': ['140', '264'],
#  '1707': ['027', '056', '079'],
#  '1708': ['026', '037', '056', '072'],
#  '17081794': ['026'],
#  '1709': ['072', '294'],
#  '1710': ['015', '079', '294'],
#  '1712': ['072', '275'],
#  '17121780': ['275'],
#  '1714': ['007', '027', '049', '053', '056', '072', '294'],
#  '17141780': ['053'],
#  '17141794': ['049'],
#  '1715': ['009', '056', '072', '294'],
#  '1716': ['221', '294'],
#  '1717': ['015', '027', '072'],
#  '1718': ['015', '072', '290', '294'],
#  '1719': ['015', '294'],
#  '1720': ['015', '027', '053', '079'],
#  '1720s': ['015', '079'],
#  '1721': ['072', '079', '294'],
#  '1722': ['015'],
#  '1723': ['072'],
#  '1724': ['072', '275', '294', '299'],
#  '1724observ': ['015'],
#  '1725': ['072'],
#  '17251729': ['090'],
#  '1728': ['027', '322'],
#  '1729': ['011'],
#  '1730': ['072'],
#  '1730s': ['066', '294'],
#  '1731': ['043', '049', '072'],
#  '1732': ['037', '162'],
#  '1733': ['279'],
#  '1734': ['275', '290', '294'],
#  '1735': ['026', '322'],
#  '1736': ['026', '135', '275', '331'],
#  '1737': ['012', '026', '290'],
#  '1738': ['066'],
#  '1739': ['049'],
#  '1740': ['015', '049', '053', '275'],
#  '174000': ['208'],
#  '1741': ['294', '295'],
#  '1742': ['066', '098'],
#  '1743': ['015', '188', '236', '294'],
#  '1744': ['066', '074', '079', '275', '294'],
#  '17441804': ['074'],
#  '1745': ['112'],
#  '1746': ['053', '170', '322'],
#  '17461748': ['275'],
#  '1747': ['026', '049', '229', '290', '294'],
#  '1748': ['086', '275'],
#  '1749': ['019', '290', '294', '305'],
#  '17491817': ['305'],
#  '17491819': ['019'],
#  '1750': ['049', '098', '126'],
#  '1750s': ['037', '086', '294'],
#  '1751': ['037'],
#  '1752': ['015', '174', '288', '331'],
#  '1753': ['011', '037', '049', '162'],
#  '1754': ['053', '069', '304'],
#  '17541826': ['304'],
#  '1755': ['009', '085', '322', '327'],
#  '17551805': ['085'],
#  '1756': ['162', '294'],
#  '1758': ['042', '049', '294'],
#  '17581840': ['042'],
#  '1759': ['162', '318', '330'],
#  '17591814': ['318'],
#  '1760': ['066', '135', '331'],
#  '1760s': ['011', '043', '066', '331'],
#  '1761': ['264'],
#  '1762': ['009', '049', '098', '269'],
#  '17621807': ['269'],
#  '1763': ['011', '026', '188'],
#  '1764': ['011', '162', '289', '290', '304'],
#  '1765': ['015', '026', '275', '279', '330'],
#  '1766': ['105', '279', '292'],
#  '17661817': ['105'],
#  '17661844': ['292'],
#  '1767': ['162', '291'],
#  '1768': ['053'],
#  '1769': ['042', '174', '188', '279'],
#  '1770': ['170', '288', '290'],
#  '1770s': ['011', '074', '135', '331'],
#  '1771': ['264'],
#  '1772': ['019', '026', '072', '074', '188', '283', '294', '330'],
#  '17721801': ['283'],
#  '1773': ['019', '135', '275'],
#  '1774': ['026', '165', '248', '305', '331'],
#  '17741844': ['165'],
#  '1775': ['019', '026', '049', '066', '162', '275', '305', '330'],
#  '1776': ['019', '040', '122', '162', '275', '304', '331'],
#  '177682': ['125'],
#  '1777': ['037', '042', '069', '228', '248', '318', '330', '331'],
#  '1778': ['066', '162', '239', '269', '304'],
#  '1779': ['042', '070', '074', '152', '318'],
#  '1780': ['042', '053', '074', '126', '228', '275', '279', '304', '330'],
#  '1780s': ['019', '043', '236'],
#  '1781': ['029', '074', '164', '228', '330'],
#  '17811831': ['164'],
#  '17811870': ['029'],
#  '1782': ['074', '153', '228', '288', '289', '318', '330'],
#  '1783': ['049', '288', '289'],
#  '1784': ['069', '098', '105', '288', '294', '304', '327'],
#  '17841846': ['098'],
#  '1785': ['001', '026', '043', '074', '086', '184', '245', '288', '318'],
#  '1786': ['019', '086', '096', '105', '170', '289', '304', '330', '331'],
#  '1787': ['026', '074', '095', '291', '330'],
#  '1788': ['174', '304', '313'],
#  '1789': ['074', '269', '288'],
#  '1790': ['074', '105', '190', '236', '283', '292'],
#  '17901850': ['304'],
#  '17901852': ['190'],
#  '1790bi': ['019'],
#  '1790s': ['069'],
#  '1791': ['026', '074', '126', '215', '259'],
#  '1792': ['074', '086', '105', '170', '185', '262', '269'],
#  '17921856': ['262'],
#  '179294': ['269'],
#  '1793': ['188', '292', '330'],
#  '1794': ['026', '049', '085', '151', '279', '283', '288', '304'],
#  '17941843': ['046'],
#  '1795': ['074', '126', '148', '152', '185', '269', '283'],
#  '1796': ['019', '070', '148', '162', '164', '174', '283', '318'],
#  '17961797': ['165'],
#  '17961832': ['148'],
#  '1797': ['254'],
#  '17971871': ['254'],
#  '1798': ['019',
#   '043',
#   '053',
#   '069',
#   '141',
#   '164',
#   '170',
#   '269',
#   '283',
#   '288',
#   '291'],
#  '1799': ['010',
#   '069',
#   '074',
#   '148',
#   '162',
#   '165',
#   '191',
#   '288',
#   '304',
#   '327'],
#  '17991865': ['191'],
#  '17stori': ['057'],
#  '17th': ['018', '044', '209', '220', '221', '327'],
#  '18': ['003',
#   '004',
#   '010',
#   '021',
#   '024',
#   '028',
#   '035',
#   '039',
#   '072',
#   '089',
#   '102',
#   '122',
#   '131',
#   '153',
#   '162',
#   '166',
#   '184',
#   '193',
#   '200',
#   '206',
#   '208',
#   '211',
#   '215',
#   '231',
#   '245',
#   '256',
#   '257',
#   '281',
#   '288',
#   '319',
#   '320',
#   '328'],
#  '180': ['065', '128', '268'],
#  '1800': ['066', '279', '283', '291', '292', '305'],
#  '18000': ['156', '208'],
#  '18000km': ['156'],
#  '1800s': ['152'],
#  '1801': ['040', '042', '063', '085', '126', '164', '283', '330'],
#  '1802': ['042', '165', '262', '269'],
#  '1803': ['105', '164', '184', '239', '292', '304'],
#  '1804': ['042',
#   '074',
#   '098',
#   '105',
#   '152',
#   '248',
#   '262',
#   '291',
#   '307',
#   '329'],
#  '1805': ['003', '085', '096', '153', '164', '174', '252'],
#  '18051859': ['252'],
#  '18051894': ['003'],
#  '1806': ['098', '135', '152', '164', '239', '288'],
#  '1807': ['042', '070', '098', '164', '190', '262', '327'],
#  '1808': ['164', '165'],
#  '1809': ['153', '267', '320'],
#  '18091862': ['320'],
#  '1810': ['029', '098', '164', '215', '242', '292', '305'],
#  '18101893': ['242'],
#  '1810s': ['259'],
#  '1811': ['040',
#   '042',
#   '097',
#   '102',
#   '105',
#   '122',
#   '190',
#   '262',
#   '310',
#   '313',
#   '318'],
#  '18111813': ['042'],
#  '18111863': ['102'],
#  '18111870': ['010'],
#  '1812': ['001', '029', '041', '095', '140', '185', '215', '304', '307'],
#  '18121813': ['029', '042'],
#  '18121888': ['041'],
#  '1813': ['105', '153', '190', '233', '309'],
#  '1814': ['016', '058', '088', '105', '148', '254', '262', '318'],
#  '18141889': ['088'],
#  '18141894': ['016'],
#  '1815': ['042',
#   '102',
#   '105',
#   '148',
#   '164',
#   '191',
#   '212',
#   '254',
#   '288',
#   '297'],
#  '181518': ['164'],
#  '18151864': ['212'],
#  '1816': ['105', '112', '122', '239', '262', '279', '316'],
#  '18161854': ['316'],
#  '18161893': ['112'],
#  '1817': ['040', '096', '105', '113', '252', '304', '305', '327'],
#  '18171902': ['113'],
#  '1818': ['070', '096', '118', '151', '164', '170', '291'],
#  '1819': ['001',
#   '019',
#   '040',
#   '095',
#   '098',
#   '148',
#   '149',
#   '190',
#   '191',
#   '239',
#   '285',
#   '304'],
#  '18191896': ['285'],
#  '18191903': ['189'],
#  '1820': ['042',
#   '087',
#   '095',
#   '165',
#   '168',
#   '190',
#   '191',
#   '239',
#   '252',
#   '288',
#   '304',
#   '316'],
#  '18201893': ['087'],
#  '1820s': ['001', '096', '113', '190'],
#  '1821': ['067', '095', '164', '239', '245', '307', '316'],
#  '1822': ['001',
#   '042',
#   '046',
#   '095',
#   '151',
#   '190',
#   '191',
#   '215',
#   '252',
#   '254',
#   '262',
#   '292',
#   '307'],
#  '18221898': ['046'],
#  '1823': ['042', '252'],
#  '1824': ['095', '098', '148', '152', '296'],
#  '1825': ['003', '040', '095', '165', '252', '259', '307', '316'],
#  '1826': ['095', '112', '184', '262', '304'],
#  '1827': ['003', '042', '164', '165', '262', '307'],
#  '18271839': ['184'],
#  '1828': ['095', '148', '153', '191', '242', '245', '252'],
#  '1829': ['102', '106', '164', '191', '252', '307', '320'],
#  '18291830': ['262'],
#  '183': ['177'],
#  '1830': ['029',
#   '069',
#   '096',
#   '102',
#   '109',
#   '152',
#   '164',
#   '185',
#   '191',
#   '288',
#   '320',
#   '329'],
#  '18301903': ['109'],
#  '1830s': ['058', '096', '098', '151', '215', '272', '329', '331'],
#  '1831': ['024', '047', '122', '242', '252', '267', '309', '316'],
#  '1832': ['003', '041', '096', '148', '215', '257', '316'],
#  '18321910': ['257'],
#  '1833': ['001', '140', '190', '191', '212', '316', '319'],
#  '1834': ['058',
#   '063',
#   '101',
#   '151',
#   '153',
#   '190',
#   '212',
#   '246',
#   '265',
#   '302'],
#  '183436': ['262'],
#  '1835': ['006',
#   '016',
#   '022',
#   '070',
#   '088',
#   '096',
#   '164',
#   '189',
#   '254',
#   '316',
#   '320'],
#  '18351900': ['006'],
#  '1836': ['029', '096', '102', '112', '113', '165', '245', '254', '309'],
#  '1837': ['058', '151', '189', '252', '274', '292', '309', '310'],
#  '1838': ['010',
#   '063',
#   '096',
#   '098',
#   '112',
#   '140',
#   '190',
#   '191',
#   '212',
#   '257',
#   '267',
#   '292',
#   '316'],
#  '1839': ['069',
#   '087',
#   '096',
#   '097',
#   '140',
#   '151',
#   '191',
#   '242',
#   '267',
#   '274',
#   '285',
#   '310',
#   '316'],
#  '1840': ['006',
#   '016',
#   '024',
#   '042',
#   '140',
#   '147',
#   '149',
#   '153',
#   '183',
#   '212',
#   '245',
#   '285',
#   '297'],
#  '18401928': ['147'],
#  '1840s': ['068', '087', '310', '329'],
#  '1841': ['058', '113', '149', '190', '270', '316', '329'],
#  '1842': ['016',
#   '046',
#   '052',
#   '113',
#   '133',
#   '165',
#   '189',
#   '191',
#   '242',
#   '262',
#   '286',
#   '316',
#   '320'],
#  '18421888': ['052'],
#  '18421923': ['286'],
#  '18421925': ['263'],
#  '1843': ['016', '096', '112', '165', '184', '189', '242', '267', '316'],
#  '1844': ['050', '058', '112', '113', '165', '168', '292', '316'],
#  '1845': ['016', '041', '046', '189', '191', '285', '286', '291'],
#  '184546': ['320'],
#  '1846': ['016', '041', '098', '140', '152', '262', '316'],
#  '1847': ['010',
#   '046',
#   '087',
#   '088',
#   '102',
#   '106',
#   '112',
#   '113',
#   '118',
#   '233',
#   '313',
#   '316'],
#  '1848': ['047', '070', '087', '088', '233', '254', '259', '263', '316'],
#  '1849': ['003', '016', '189', '212', '285', '309', '314', '316'],
#  '18491936': ['314'],
#  '1850': ['046', '066', '149', '189', '233', '254', '259', '296', '316'],
#  '1850s': ['087', '102', '138', '262', '313', '331'],
#  '1851': ['029', '097', '189', '285', '307'],
#  '1852': ['016',
#   '047',
#   '058',
#   '087',
#   '109',
#   '112',
#   '152',
#   '189',
#   '190',
#   '239'],
#  '1853': ['006',
#   '010',
#   '016',
#   '022',
#   '087',
#   '101',
#   '119',
#   '138',
#   '252',
#   '254'],
#  '1854': ['003',
#   '116',
#   '168',
#   '175',
#   '181',
#   '189',
#   '212',
#   '231',
#   '263',
#   '308',
#   '309',
#   '316'],
#  '18541899': ['116'],
#  '18541932': ['175'],
#  '18541934': ['231'],
#  '1855': ['097',
#   '109',
#   '112',
#   '149',
#   '168',
#   '233',
#   '242',
#   '252',
#   '254',
#   '316'],
#  '1856': ['003',
#   '006',
#   '024',
#   '057',
#   '059',
#   '094',
#   '101',
#   '165',
#   '168',
#   '180',
#   '233',
#   '246',
#   '256',
#   '258',
#   '262',
#   '302',
#   '319'],
#  '18561920': ['258'],
#  '18561937': ['256'],
#  '18561950': ['094'],
#  '1857': ['014',
#   '016',
#   '022',
#   '111',
#   '168',
#   '189',
#   '212',
#   '237',
#   '242',
#   '302'],
#  '1858': ['002', '003', '016', '022', '302', '306', '309'],
#  '18581918': ['306'],
#  '1859': ['003', '087', '109', '252', '254', '258', '302', '320'],
#  '1860': ['016',
#   '024',
#   '041',
#   '050',
#   '052',
#   '068',
#   '087',
#   '101',
#   '113',
#   '149',
#   '175',
#   '191',
#   '233',
#   '246',
#   '285',
#   '296',
#   '302'],
#  '18601862': ['024'],
#  '18601940': ['068'],
#  '1860s': ['024', '041', '097', '101'],
#  '1861': ['006', '113', '118', '167', '191', '242', '296'],
#  '1862': ['006', '040', '147', '263', '320'],
#  '18621865': ['024'],
#  '18621890': ['084'],
#  '1863': ['008', '017', '024', '063', '097', '102', '183', '191', '278'],
#  '1864': ['024', '113', '183', '212', '215', '242', '263', '319'],
#  '1865': ['084', '088', '106', '118', '136', '149', '183', '250', '257'],
#  '18651939': ['136'],
#  '18651949': ['250'],
#  '1866': ['010',
#   '022',
#   '024',
#   '149',
#   '173',
#   '254',
#   '257',
#   '259',
#   '285',
#   '310'],
#  '1867': ['016', '018', '024', '052', '101', '114', '147', '286', '296'],
#  '1868': ['006', '052', '101', '112', '149', '262', '313', '327'],
#  '1869': ['003',
#   '024',
#   '046',
#   '052',
#   '087',
#   '088',
#   '246',
#   '257',
#   '302',
#   '310'],
#  '1870': ['006', '010', '016', '024', '029', '101', '245', '249'],
#  '18701937': ['249'],
#  '187071': ['017', '109'],
#  '1870s': ['024', '047', '109'],
#  '1871': ['013',
#   '057',
#   '087',
#   '103',
#   '109',
#   '138',
#   '147',
#   '181',
#   '185',
#   '187',
#   '215',
#   '257',
#   '262',
#   '293',
#   '302',
#   '310'],
#  '18711950': ['293'],
#  '1872': ['024', '087', '116', '138', '147', '270', '274'],
#  '187276': ['270'],
#  '1873': ['006',
#   '016',
#   '044',
#   '052',
#   '065',
#   '088',
#   '101',
#   '274',
#   '310',
#   '319'],
#  '187376': ['270'],
#  '1874': ['024', '088', '101', '109', '147'],
#  '1875': ['003',
#   '058',
#   '059',
#   '097',
#   '143',
#   '173',
#   '256',
#   '257',
#   '285',
#   '286'],
#  '18751881': ['058'],
#  '18751912': ['321'],
#  '18751955': ['143'],
#  '1876': ['063', '088', '094', '116', '180', '231', '270'],
#  '1877': ['016', '024', '046', '052', '063', '230', '231', '258', '286'],
#  '1878': ['041', '052', '111', '119', '147', '219', '256', '285', '286'],
#  '1879': ['003',
#   '021',
#   '023',
#   '057',
#   '058',
#   '084',
#   '116',
#   '119',
#   '185',
#   '314'],
#  '18791936': ['021'],
#  '1880': ['022', '046', '097', '175', '181', '274', '281', '310', '319'],
#  '1880s': ['041', '109', '111', '189', '308'],
#  '1881': ['022',
#   '175',
#   '231',
#   '256',
#   '258',
#   '274',
#   '302',
#   '306',
#   '319',
#   '327'],
#  '1882': ['048', '109', '133', '185', '308'],
#  '18821945': ['048'],
#  '1883': ['022', '068', '115', '231', '242', '250', '257', '270', '314'],
#  '18831889': ['111'],
#  '18831970': ['115'],
#  '1884': ['014', '059', '068', '073', '116', '166', '175', '256', '312'],
#  '1885': ['068', '109', '119', '136', '175', '222', '256', '308', '325'],
#  '1886': ['116', '147', '250', '258', '327'],
#  '1887': ['087', '147', '173', '263'],
#  '1888': ['003',
#   '054',
#   '059',
#   '076',
#   '088',
#   '133',
#   '175',
#   '184',
#   '250',
#   '263',
#   '277',
#   '323'],
#  '18881946': ['076'],
#  '1889': ['003', '088', '100', '136', '175', '202', '250', '257', '323'],
#  '1890': ['002', '064', '084', '094', '106', '205', '314'],
#  '18901974': ['205'],
#  '1890s': ['024', '109', '141', '256', '257'],
#  '1891': ['002',
#   '006',
#   '044',
#   '059',
#   '094',
#   '108',
#   '143',
#   '147',
#   '250',
#   '254',
#   '258',
#   '293',
#   '308',
#   '323'],
#  '18911892': ['258', '293'],
#  '1892': ['017', '046', '055', '075', '145', '149', '205', '250'],
#  '18921893': ['250'],
#  '1892at': ['017', '149'],
#  '1893': ['013',
#   '057',
#   '065',
#   '087',
#   '189',
#   '237',
#   '242',
#   '250',
#   '267',
#   '286'],
#  '1894': ['003',
#   '016',
#   '020',
#   '050',
#   '055',
#   '057',
#   '116',
#   '124',
#   '136',
#   '257',
#   '270',
#   '286',
#   '293',
#   '302',
#   '323'],
#  '18941896': ['323'],
#  '18941969': ['055'],
#  '1895': ['136', '147', '249', '323', '328'],
#  '1896': ['044',
#   '106',
#   '142',
#   '143',
#   '257',
#   '265',
#   '288',
#   '291',
#   '293',
#   '308'],
#  '1897': ['002',
#   '050',
#   '094',
#   '108',
#   '109',
#   '113',
#   '116',
#   '136',
#   '147',
#   '180',
#   '256',
#   '257',
#   '258',
#   '286'],
#  '1898': ['006', '094', '143', '147', '233', '250', '251', '253', '258'],
#  '18981964': ['251'],
#  '1899': ['009', '018', '024', '044', '077', '116', '136', '250'],
#  '18m': ['190'],
#  '18th': ['015', '027', '129', '221', '263', '305', '322'],
#  '18thcenturi': ['305'],
#  '19': ['003',
#   '004',
#   '071',
#   '096',
#   '097',
#   '101',
#   '108',
#   '130',
#   '147',
#   '161',
#   '212',
#   '233',
#   '260',
#   '271',
#   '272',
#   '287',
#   '289',
#   '297',
#   '307',
#   '318',
#   '323',
#   '325'],
#  '1900': ['002',
#   '023',
#   '049',
#   '075',
#   '136',
#   '181',
#   '196',
#   '257',
#   '263',
#   '276',
#   '293',
#   '297',
#   '300'],
#  '1901': ['009',
#   '013',
#   '018',
#   '050',
#   '081',
#   '136',
#   '154',
#   '231',
#   '250',
#   '258',
#   '306',
#   '314'],
#  '190103': ['250'],
#  '19011983': ['227'],
#  '1902': ['005',
#   '013',
#   '017',
#   '065',
#   '092',
#   '108',
#   '133',
#   '196',
#   '227',
#   '238',
#   '247',
#   '249',
#   '250',
#   '257',
#   '258',
#   '265',
#   '286'],
#  '19021977': ['238'],
#  '19021992': ['133'],
#  '19021994': ['092'],
#  '19021995': ['005'],
#  '190220': ['006'],
#  '1902at': ['189'],
#  '1903': ['023',
#   '109',
#   '111',
#   '136',
#   '147',
#   '189',
#   '202',
#   '250',
#   '256',
#   '258',
#   '260',
#   '265',
#   '293',
#   '306',
#   '314'],
#  '19031930': ['260'],
#  '19031995': ['202'],
#  '1904': ['014',
#   '023',
#   '062',
#   '104',
#   '114',
#   '116',
#   '136',
#   '181',
#   '250',
#   '257',
#   '271',
#   '298',
#   '314',
#   '325'],
#  '1905': ['021',
#   '022',
#   '023',
#   '030',
#   '059',
#   '111',
#   '113',
#   '154',
#   '159',
#   '180',
#   '230',
#   '250',
#   '257',
#   '258',
#   '270',
#   '293'],
#  '1906': ['002',
#   '051',
#   '061',
#   '065',
#   '071',
#   '073',
#   '076',
#   '103',
#   '117',
#   '121',
#   '129',
#   '130',
#   '154',
#   '167',
#   '180',
#   '181',
#   '250',
#   '258',
#   '263',
#   '265',
#   '321'],
#  '19061972': ['121'],
#  '19061979': ['130'],
#  '19062004': ['061'],
#  '1907': ['023',
#   '048',
#   '119',
#   '150',
#   '158',
#   '166',
#   '167',
#   '169',
#   '173',
#   '245',
#   '246',
#   '256',
#   '312'],
#  '1908': ['048', '111', '133', '147', '181', '258', '268', '325'],
#  '190809': ['258'],
#  '1908he': ['023'],
#  '1909': ['020', '023', '048', '154', '205', '258', '278', '308', '321'],
#  '1910': ['023',
#   '028',
#   '048',
#   '075',
#   '082',
#   '091',
#   '154',
#   '166',
#   '168',
#   '211',
#   '237',
#   '249',
#   '250',
#   '257',
#   '278',
#   '293',
#   '308',
#   '321'],
#  '1910s': ['044', '064'],
#  '1911': ['021',
#   '048',
#   '082',
#   '110',
#   '111',
#   '136',
#   '154',
#   '173',
#   '249',
#   '258',
#   '278',
#   '321'],
#  '1912': ['021',
#   '023',
#   '048',
#   '082',
#   '101',
#   '143',
#   '160',
#   '163',
#   '181',
#   '249',
#   '258',
#   '277',
#   '321'],
#  '19121954': ['222'],
#  '1913': ['021',
#   '048',
#   '060',
#   '082',
#   '094',
#   '205',
#   '231',
#   '258',
#   '263',
#   '325'],
#  '19132012': ['060'],
#  '1914': ['021',
#   '032',
#   '048',
#   '097',
#   '115',
#   '116',
#   '123',
#   '124',
#   '136',
#   '205',
#   '249',
#   '267',
#   '270',
#   '293'],
#  '19141997': ['123'],
#  '1915': ['044',
#   '048',
#   '055',
#   '064',
#   '100',
#   '115',
#   '198',
#   '231',
#   '257',
#   '260',
#   '293'],
#  '1916': ['044', '047', '065', '115', '230', '251', '312'],
#  '19162001': ['225'],
#  '1917': ['013',
#   '022',
#   '048',
#   '101',
#   '103',
#   '109',
#   '136',
#   '145',
#   '166',
#   '205',
#   '293'],
#  '1918': ['023', '092', '124', '180', '227', '280', '293', '300', '306'],
#  '1919': ['092',
#   '103',
#   '112',
#   '130',
#   '133',
#   '154',
#   '165',
#   '166',
#   '186',
#   '231',
#   '247',
#   '251',
#   '277',
#   '300',
#   '328'],
#  '192': ['056'],
#  '1920': ['055',
#   '064',
#   '082',
#   '093',
#   '094',
#   '166',
#   '231',
#   '247',
#   '258',
#   '325',
#   '328'],
#  '19201958': ['093'],
#  '1920s': ['004',
#   '020',
#   '065',
#   '108',
#   '142',
#   '144',
#   '154',
#   '166',
#   '230',
#   '263',
#   '278',
#   '306'],
#  '1921': ['014',
#   '020',
#   '023',
#   '055',
#   '064',
#   '071',
#   '100',
#   '103',
#   '108',
#   '121',
#   '133',
#   '231',
#   '249',
#   '260'],
#  '1922': ['014',
#   '050',
#   '065',
#   '094',
#   '100',
#   '108',
#   '115',
#   '136',
#   '247',
#   '251',
#   '253',
#   '293',
#   '297',
#   '300'],
#  '1923': ['071',
#   '076',
#   '089',
#   '094',
#   '124',
#   '136',
#   '193',
#   '210',
#   '227',
#   '260',
#   '272',
#   '286',
#   '328'],
#  '19232003': ['193'],
#  '19232008': ['210'],
#  '1924': ['020',
#   '021',
#   '057',
#   '076',
#   '077',
#   '117',
#   '121',
#   '143',
#   '158',
#   '251',
#   '260',
#   '263',
#   '297'],
#  '192427': ['133'],
#  '1925': ['021',
#   '068',
#   '076',
#   '081',
#   '082',
#   '092',
#   '094',
#   '100',
#   '103',
#   '108',
#   '202',
#   '238',
#   '253',
#   '260',
#   '268',
#   '271',
#   '277',
#   '293',
#   '303',
#   '314',
#   '328'],
#  '1926': ['048',
#   '076',
#   '077',
#   '100',
#   '103',
#   '137',
#   '158',
#   '202',
#   '260',
#   '277',
#   '278'],
#  '1927': ['005',
#   '023',
#   '030',
#   '061',
#   '071',
#   '075',
#   '097',
#   '100',
#   '108',
#   '124',
#   '125',
#   '133',
#   '142',
#   '159',
#   '192',
#   '194',
#   '247',
#   '249',
#   '251',
#   '277',
#   '300'],
#  '1928': ['004',
#   '030',
#   '051',
#   '076',
#   '092',
#   '103',
#   '104',
#   '108',
#   '129',
#   '136',
#   '147',
#   '158',
#   '220',
#   '238',
#   '251',
#   '260',
#   '268',
#   '271',
#   '277',
#   '293',
#   '312',
#   '322',
#   '328'],
#  '1929': ['018',
#   '020',
#   '055',
#   '062',
#   '073',
#   '075',
#   '092',
#   '117',
#   '123',
#   '131',
#   '137',
#   '142',
#   '143',
#   '156',
#   '166',
#   '251',
#   '268',
#   '277'],
#  '19291941': ['137'],
#  '1930': ['005',
#   '076',
#   '117',
#   '121',
#   '128',
#   '130',
#   '140',
#   '156',
#   '157',
#   '158',
#   '166',
#   '202',
#   '205',
#   '227',
#   '260',
#   '280',
#   '293',
#   '298',
#   '300',
#   '328'],
#  '19301932': ['143'],
#  '1930s': ['014',
#   '020',
#   '023',
#   '048',
#   '064',
#   '073',
#   '107',
#   '150',
#   '159',
#   '186',
#   '205',
#   '222',
#   '249',
#   '253',
#   '268',
#   '271',
#   '280',
#   '293',
#   '300',
#   '312',
#   '328'],
#  '1931': ['020',
#   '061',
#   '076',
#   '115',
#   '128',
#   '133',
#   '142',
#   '150',
#   '156',
#   '158',
#   '173',
#   '205',
#   '206',
#   '250',
#   '271',
#   '293',
#   '298'],
#  '1931with': ['271'],
#  '1932': ['028',
#   '075',
#   '076',
#   '128',
#   '142',
#   '150',
#   '157',
#   '158',
#   '159',
#   '175',
#   '251',
#   '271',
#   '297'],
#  '1933': ['005',
#   '054',
#   '059',
#   '061',
#   '075',
#   '081',
#   '110',
#   '128',
#   '130',
#   '137',
#   '143',
#   '157',
#   '166',
#   '250',
#   '251',
#   '253',
#   '260',
#   '268',
#   '271',
#   '293'],
#  '1934': ['023',
#   '051',
#   '060',
#   '077',
#   '081',
#   '092',
#   '104',
#   '107',
#   '117',
#   '128',
#   '137',
#   '157',
#   '158',
#   '186',
#   '207',
#   '219',
#   '231',
#   '238',
#   '271',
#   '280',
#   '300',
#   '312'],
#  '1935': ['021',
#   '051',
#   '123',
#   '130',
#   '150',
#   '158',
#   '186',
#   '211',
#   '238',
#   '250',
#   '268',
#   '293'],
#  '1936': ['005',
#   '060',
#   '076',
#   '081',
#   '082',
#   '142',
#   '143',
#   '150',
#   '158',
#   '167',
#   '202',
#   '210',
#   '220',
#   '237',
#   '268',
#   '271',
#   '328'],
#  '1937': ['005',
#   '051',
#   '068',
#   '081',
#   '092',
#   '103',
#   '107',
#   '110',
#   '114',
#   '123',
#   '150',
#   '167',
#   '177',
#   '197',
#   '198',
#   '215',
#   '220',
#   '222',
#   '225',
#   '249',
#   '256',
#   '268',
#   '271',
#   '329'],
#  '19371938': ['202'],
#  '1938': ['005',
#   '030',
#   '093',
#   '094',
#   '100',
#   '123',
#   '142',
#   '144',
#   '205',
#   '209',
#   '211',
#   '222',
#   '238',
#   '251',
#   '293'],
#  '1939': ['005',
#   '018',
#   '020',
#   '023',
#   '055',
#   '060',
#   '076',
#   '077',
#   '081',
#   '107',
#   '121',
#   '124',
#   '130',
#   '136',
#   '137',
#   '143',
#   '156',
#   '179',
#   '202',
#   '227',
#   '251',
#   '276',
#   '293',
#   '327'],
#  '193967': ['271'],
#  '1940': ['055', '059', '100', '137', '156', '167', '180', '268'],
#  '1940s': ['077', '121', '186', '198', '199', '205', '253', '297'],
#  '1941': ['028',
#   '054',
#   '076',
#   '093',
#   '121',
#   '167',
#   '179',
#   '202',
#   '210',
#   '211',
#   '216',
#   '272',
#   '280',
#   '282'],
#  '19412011': ['216'],
#  '1942': ['005',
#   '077',
#   '133',
#   '137',
#   '167',
#   '198',
#   '208',
#   '211',
#   '227',
#   '251',
#   '271',
#   '280'],
#  '1943': ['028', '094', '208', '300', '303'],
#  '1944': ['017',
#   '030',
#   '051',
#   '076',
#   '125',
#   '133',
#   '137',
#   '192',
#   '194',
#   '211',
#   '238',
#   '276',
#   '293'],
#  '1945': ['048',
#   '060',
#   '091',
#   '093',
#   '117',
#   '121',
#   '130',
#   '133',
#   '137',
#   '159',
#   '194',
#   '208',
#   '271'],
#  '1946': ['005',
#   '023',
#   '060',
#   '065',
#   '076',
#   '100',
#   '108',
#   '123',
#   '197',
#   '208',
#   '210',
#   '214',
#   '227',
#   '239',
#   '300'],
#  '1947': ['028',
#   '093',
#   '100',
#   '108',
#   '137',
#   '143',
#   '219',
#   '251',
#   '271',
#   '276'],
#  '1948': ['061', '115', '125', '134', '193', '208', '225', '271', '298'],
#  '19481970': ['108'],
#  '1949': ['051',
#   '055',
#   '073',
#   '077',
#   '092',
#   '134',
#   '143',
#   '225',
#   '250',
#   '300',
#   '303'],
#  '1950': ['061',
#   '073',
#   '092',
#   '093',
#   '094',
#   '100',
#   '121',
#   '125',
#   '129',
#   '194',
#   '210',
#   '222',
#   '238',
#   '251',
#   '268',
#   '298',
#   '303'],
#  '1950s': ['020',
#   '073',
#   '091',
#   '092',
#   '097',
#   '134',
#   '155',
#   '166',
#   '192',
#   '197',
#   '224',
#   '303'],
#  '1951': ['060', '087', '093', '096', '194', '195', '196', '280', '303'],
#  '1952': ['030', '032', '055', '129', '143', '201', '210', '222', '271'],
#  '1953': ['013',
#   '059',
#   '073',
#   '093',
#   '107',
#   '129',
#   '134',
#   '167',
#   '193',
#   '201',
#   '247',
#   '280',
#   '328'],
#  '1954': ['073', '116', '128', '130', '131', '194', '202', '222', '271'],
#  '1955': ['051',
#   '060',
#   '061',
#   '077',
#   '125',
#   '143',
#   '159',
#   '186',
#   '205',
#   '206',
#   '210',
#   '251'],
#  '1956': ['062',
#   '093',
#   '103',
#   '107',
#   '194',
#   '201',
#   '209',
#   '210',
#   '230',
#   '271',
#   '280'],
#  '1956350': ['186'],
#  '1957': ['060',
#   '061',
#   '071',
#   '129',
#   '130',
#   '134',
#   '194',
#   '199',
#   '201',
#   '253',
#   '263',
#   '277',
#   '300',
#   '303'],
#  '195758': ['239'],
#  '1958': ['005',
#   '028',
#   '060',
#   '081',
#   '093',
#   '104',
#   '134',
#   '146',
#   '179',
#   '209',
#   '276',
#   '301'],
#  '1959': ['028', '100', '104', '192', '194', '207', '276', '280', '315'],
#  '1959he': ['209'],
#  '1959the': ['199'],
#  '1960': ['060', '124', '186', '198', '200', '207', '209', '251', '303'],
#  '1960s': ['014',
#   '020',
#   '061',
#   '064',
#   '091',
#   '092',
#   '116',
#   '129',
#   '199',
#   '205',
#   '268'],
#  '1961': ['060', '065', '121', '134', '194', '251', '300'],
#  '1962': ['093', '131', '194', '209', '213', '300'],
#  '1963': ['005',
#   '073',
#   '092',
#   '121',
#   '124',
#   '125',
#   '129',
#   '194',
#   '199',
#   '201',
#   '207',
#   '209',
#   '213',
#   '223',
#   '268',
#   '271',
#   '319'],
#  '1964': ['115', '129', '130', '131', '210', '251', '271', '276', '301'],
#  '1965': ['089', '092', '123', '129', '130', '146', '192'],
#  '1966': ['146', '169', '192', '210', '267', '280'],
#  '1967': ['117', '146', '197', '216', '268'],
#  '1968': ['032', '207', '209', '213', '216', '223', '227', '266', '271'],
#  '1969': ['005',
#   '092',
#   '130',
#   '155',
#   '163',
#   '194',
#   '197',
#   '199',
#   '203',
#   '214',
#   '218',
#   '219'],
#  '1970': ['104',
#   '115',
#   '130',
#   '155',
#   '177',
#   '193',
#   '207',
#   '210',
#   '213',
#   '238',
#   '276'],
#  '197000': ['090'],
#  '1970s': ['032',
#   '089',
#   '091',
#   '116',
#   '123',
#   '131',
#   '138',
#   '194',
#   '196',
#   '203'],
#  '1971': ['071', '100', '133', '192', '214', '216'],
#  '1972': ['092', '123', '182', '197', '198', '207', '224', '253', '303'],
#  '1973': ['061', '123', '155', '186', '195', '197', '202'],
#  '1974': ['028', '108', '125', '155', '253', '268'],
#  '1975': ['089', '262', '267'],
#  '1976': ['064', '110', '193', '195', '209', '210', '303'],
#  '1977': ['125', '195', '210', '238'],
#  '1978': ['127', '155', '177', '197', '204', '216', '289'],
#  '197879': ['195'],
#  '1979': ['062', '150', '155', '179', '193', '195', '201', '207'],
#  '1980': ['077',
#   '084',
#   '120',
#   '131',
#   '192',
#   '195',
#   '197',
#   '200',
#   '202',
#   '203',
#   '303',
#   '311'],
#  '1980s': ['116', '193', '194', '203', '210', '258', '327'],
#  '1981': ['061', '107', '159', '193'],
#  '1982': ['197', '201', '216'],
#  '1983': ['030', '133', '158', '193', '195', '197', '203', '216'],
#  '1984': ['028', '111', '182', '203', '311'],
#  '19841985': ['195'],
#  '1985': ['110', '127', '186', '203', '206', '212', '224', '303'],
#  '1986': ['061', '110', '194', '197', '319'],
#  '1987': ['075', '192', '223', '280'],
#  '1987a': ['280'],
#  '1988': ['187', '192', '207', '223', '280', '303'],
#  '1989': ['203', '280', '303'],
#  '1990': ['078', '104', '123', '127', '182', '192', '205', '206', '216'],
#  '1990s': ['182', '193', '203', '207'],
#  '1991': ['203', '215', '218', '219', '287'],
#  '1992': ['206', '319'],
#  '1993': ['177', '187'],
#  '1994': ['017', '028', '091', '092', '177', '192', '207', '266'],
#  '1995': ['005', '078', '125', '144', '207', '211', '220', '280'],
#  '1996': ['089', '208', '210', '303'],
#  '1997': ['078', '110', '123', '200', '216', '327'],
#  '1998': ['073', '131', '211', '216', '217', '262', '297'],
#  '1999': ['064', '089', '156', '165', '207', '216'],
#  '19th': ['003',
#   '015',
#   '057',
#   '069',
#   '073',
#   '084',
#   '113',
#   '116',
#   '119',
#   '139',
#   '147',
#   '185',
#   '211',
#   '215',
#   '244',
#   '245',
#   '291',
#   '302',
#   '309',
#   '311',
#   '316'],
#  '19yearold': ['001'],
#  '1st': ['010', '072', '083', '100', '169', '171', '172', '179', '189', '275'],
#  '20': ['002',
#   '003',
#   '017',
#   '033',
#   '039',
#   '070',
#   '088',
#   '100',
#   '103',
#   '105',
#   '129',
#   '140',
#   '145',
#   '150',
#   '160',
#   '182',
#   '195',
#   '201',
#   '208',
#   '224',
#   '233',
#   '234',
#   '239',
#   '258',
#   '277',
#   '280',
#   '284',
#   '292',
#   '298',
#   '317',
#   '323',
#   '327',
#   '331'],
#  '200': ['065', '128', '177', '183', '190'],
#  '2000': ['097', '129', '155', '157', '208', '244', '254', '279', '301'],
#  '20000': ['016', '076', '240'],
#  '200000': ['206'],
#  '2000000': ['145'],
#  '2001': ['144', '182', '194'],
#  '2002': ['181', '186', '218', '267'],
#  '2003': ['129', '193', '206', '210'],
#  '2004': ['017', '046', '061', '197', '223'],
#  '2005': ['117', '196', '203', '209'],
#  '2006': ['048', '140', '196'],
#  '2007': ['150', '200', '221', '249'],
#  '2008': ['110', '200', '210', '248', '301'],
#  '2009': ['212'],
#  '200th': ['143'],
#  '2010': ['177', '181', '184', '211', '214'],
#  '2010s': ['301'],
#  '2011': ['192', '216', '217', '222', '272'],
#  '2012': ['017', '196', '197', '209', '287'],
#  '2013': ['153', '267'],
#  '2014': ['089'],
#  '2040': ['182'],
#  '2068': ['125'],
#  '20round': ['157'],
#  '20th': ['044',
#   '077',
#   '092',
#   '100',
#   '107',
#   '131',
#   '133',
#   '136',
#   '143',
#   '159',
#   '185',
#   '244',
#   '253',
#   '258',
#   '285',
#   '289',
#   '302',
#   '306'],
#  '20thcenturi': ['159', '244'],
#  '20year': ['134'],
#  '21': ['001',
#   '032',
#   '069',
#   '072',
#   '099',
#   '102',
#   '128',
#   '138',
#   '145',
#   '156',
#   '159',
#   '216',
#   '229',
#   '236',
#   '259',
#   '277',
#   '289',
#   '299',
#   '316',
#   '328'],
#  '2100km': ['258'],
#  '214': ['011', '048', '166'],
#  '217': ['144'],
#  '21yearold': ['225'],
#  '22': ['016',
#   '031',
#   '068',
#   '076',
#   '098',
#   '105',
#   '127',
#   '130',
#   '154',
#   '158',
#   '182',
#   '188',
#   '197',
#   '235',
#   '241',
#   '260',
#   '282',
#   '302',
#   '330'],
#  '220': ['169'],
#  '225': ['140', '262'],
#  '226000': ['134'],
#  '23': ['021',
#   '029',
#   '030',
#   '039',
#   '040',
#   '051',
#   '056',
#   '063',
#   '067',
#   '079',
#   '083',
#   '089',
#   '097',
#   '102',
#   '126',
#   '132',
#   '135',
#   '140',
#   '157',
#   '158',
#   '187',
#   '192',
#   '193',
#   '200',
#   '222',
#   '226',
#   '237',
#   '243',
#   '244',
#   '250',
#   '254',
#   '255',
#   '257',
#   '258',
#   '261',
#   '277',
#   '285',
#   '300',
#   '303',
#   '304',
#   '311',
#   '312',
#   '324'],
#  '2300': ['214'],
#  '2302': ['128'],
#  '24': ['021',
#   '029',
#   '096',
#   '099',
#   '125',
#   '153',
#   '156',
#   '162',
#   '166',
#   '171',
#   '175',
#   '186',
#   '208',
#   '235',
#   '238',
#   '262',
#   '279',
#   '302',
#   '326'],
#  '240': ['163', '301'],
#  '2436mm': ['021'],
#  '247': ['331'],
#  '24meter': ['123'],
#  '24th': ['067'],
#  '25': ['003',
#   '025',
#   '028',
#   '038',
#   '066',
#   '067',
#   '073',
#   '075',
#   '093',
#   '105',
#   '116',
#   '124',
#   '139',
#   '152',
#   '155',
#   '160',
#   '179',
#   '185',
#   '186',
#   '193',
#   '200',
#   '209',
#   '213',
#   '215',
#   '231',
#   '235',
#   '239',
#   '240',
#   '249',
#   '264',
#   '268',
#   '283',
#   '305',
#   '323'],
#  '250': ['211'],
#  '2500': ['026', '209', '227'],
#  '25000': ['247'],
#  '250000': ['060'],
#  '258': ['032'],
#  '25th': ['320'],
#  '25yearold': ['247'],
#  '26': ['027',
#   '065',
#   '076',
#   '094',
#   '098',
#   '107',
#   '118',
#   '120',
#   '123',
#   '149',
#   '154',
#   '176',
#   '178',
#   '184',
#   '215',
#   '240',
#   '260',
#   '263',
#   '275',
#   '292',
#   '304',
#   '305'],
#  '260': ['012'],
#  '263': ['137'],
#  '26gun': ['056'],
#  '26th': ['076'],
#  '27': ['025',
#   '026',
#   '029',
#   '034',
#   '064',
#   '074',
#   '081',
#   '084',
#   '095',
#   '101',
#   '122',
#   '146',
#   '153',
#   '183',
#   '203',
#   '217',
#   '231',
#   '241',
#   '256',
#   '265',
#   '293',
#   '314'],
#  '28': ['010',
#   '023',
#   '024',
#   '025',
#   '042',
#   '046',
#   '052',
#   '063',
#   '092',
#   '121',
#   '126',
#   '136',
#   '138',
#   '150',
#   '152',
#   '170',
#   '182',
#   '185',
#   '243',
#   '258',
#   '271',
#   '277',
#   '278',
#   '283',
#   '294',
#   '303',
#   '331'],
#  '280km': ['258'],
#  '2830': ['156'],
#  '2881': ['165'],
#  '28th': ['165'],
#  '29': ['024',
#   '042',
#   '054',
#   '062',
#   '074',
#   '088',
#   '091',
#   '120',
#   '150',
#   '151',
#   '167',
#   '181',
#   '199',
#   '202',
#   '242',
#   '294'],
#  '2910': ['125'],
#  '299792458': ['285'],
#  '2a': ['312'],
#  '2nd': ['113', '146', '171'],
#  '2ndcenturi': ['282'],
#  '30': ['023',
#   '028',
#   '052',
#   '053',
#   '056',
#   '061',
#   '068',
#   '072',
#   '074',
#   '088',
#   '090',
#   '119',
#   '134',
#   '149',
#   '150',
#   '155',
#   '159',
#   '164',
#   '165',
#   '180',
#   '185',
#   '196',
#   '198',
#   '208',
#   '243',
#   '262',
#   '267',
#   '285',
#   '294',
#   '295',
#   '302'],
#  '300': ['082', '190', '233', '244', '329'],
#  '3000': ['089', '129', '146', '197'],
#  '30000': ['010'],
#  '300000': ['137'],
#  '30105': ['068'],
#  '305': ['025'],
#  '306': ['025'],
#  '307': ['025'],
#  '30km': ['060'],
#  '30line': ['076'],
#  '30s': ['154', '306'],
#  '30th': ['060', '303'],
#  '31': ['022', '048', '060', '089', '149', '208', '215', '245', '316'],
#  '310': ['284'],
#  '312': ['025'],
#  '313': ['025'],
#  '313300': ['285'],
#  '32': ['186', '208', '250'],
#  '320': ['244'],
#  '3222': ['098'],
#  '33': ['246'],
#  '330': ['244'],
#  '3300': ['287'],
#  '333': ['231', '303'],
#  '335': ['247'],
#  '3380': ['183'],
#  '33rd': ['208'],
#  '34': ['021', '027', '062', '265', '323'],
#  '3420': ['199'],
#  '3477': ['125'],
#  '35': ['021', '062', '091', '107', '109', '282'],
#  '350': ['026'],
#  '350000': ['303'],
#  '35km': ['052'],
#  '35mm': ['021'],
#  '35s': ['224'],
#  '35th': ['214'],
#  '36': ['021', '103', '148', '315'],
#  '360': ['199'],
#  '3600': ['247'],
#  '36000': ['331'],
#  '3645': ['210'],
#  '365': ['282'],
#  '36mm': ['021'],
#  '36pwhippl': ['061'],
#  '37': ['014', '024', '105', '219'],
#  '370': ['176'],
#  '3724': ['178'],
#  '37inch': ['081'],
#  '38': ['099', '316'],
#  '387': ['034'],
#  '39': ['077'],
#  '393': ['177'],
#  '3d': ['013', '200', '223', '256', '287'],
#  '3dimension': ['170'],
#  '3manifold': ['181'],
#  '3meter': ['123'],
#  '3rd': ['081', '172'],
#  '3rdcenturi': ['284'],
#  '3rdcenturyc': ['034'],
#  '3sphere': ['181'],
#  '3year': ['093'],
#  '40': ['039', '089', '109', '128', '172', '182', '201', '231'],
#  '400': ['103', '167', '213', '240', '253'],
#  '4000': ['042', '270', '317'],
#  '40000': ['023', '169', '182', '311'],
#  '4004': ['214'],
#  '400c': ['089'],
#  '401': ['307'],
#  '402': ['307'],
#  '408': ['034', '163'],
#  '40th': ['155'],
#  '40year': ['305'],
#  '42': ['031', '168'],
#  '42773': ['322'],
#  '43': ['133', '268', '330'],
#  '435': ['184'],
#  '43km': ['134'],
#  '45': ['103', '116', '199', '287', '311', '314'],
#  '450': ['200', '244'],
#  '4500': ['209'],
#  '4500kg': ['276'],
#  '46': ['067', '072'],
#  '46000': ['155'],
#  '47': ['026', '080'],
#  '48': ['125'],
#  '49': ['212', '282'],
#  '4950': ['199'],
#  '4bit': ['214'],
#  '4he': ['144'],
#  '4th': ['023', '058', '169', '172', '218', '263', '284', '322'],
#  '50': ['021',
#   '077',
#   '085',
#   '158',
#   '177',
#   '190',
#   '271',
#   '282',
#   '287',
#   '289',
#   '301',
#   '307'],
#  '500': ['024', '076', '089', '169', '187', '245', '253', '309'],
#  '5000': ['048', '073', '078', '175', '208'],
#  '50000': ['098'],
#  '500000': ['078', '179', '204', '208', '311', '313'],
#  '500m': ['082'],
#  '500page': ['246'],
#  '508': ['039'],
#  '50kbit': ['199'],
#  '50kg': ['287'],
#  '50mm': ['021'],
#  '50th': ['208', '301'],
#  '51': ['093', '136'],
#  '510': ['039'],
#  '512k': ['195'],
#  '513': ['039'],
#  '518': ['039'],
#  '52': ['172'],
#  '520': ['039'],
#  '525': ['039'],
#  '53': ['160', '294'],
#  '535': ['039'],
#  '53rd': ['254'],
#  '54': ['119'],
#  '547': ['141'],
#  '548': ['043'],
#  '55': ['017', '023', '112', '294'],
#  '550': ['023'],
#  '5500': ['319'],
#  '56': ['024', '087'],
#  '57': ['164'],
#  '570': ['039'],
#  '58th': ['045'],
#  '59': ['010'],
#  '5th': ['017'],
#  '60': ['070', '094', '134', '144', '187', '243', '246'],
#  '600': ['073'],
#  '6000': ['071', '205', '207', '232', '317'],
#  '60000': ['090', '162', '272'],
#  '61': ['098', '167'],
#  '615': ['269'],
#  '61inch': ['127'],
#  '62': ['098'],
#  '625': ['268'],
#  '63': ['048', '080'],
#  '63289': ['099'],
#  '634': ['141'],
#  '6357': ['099'],
#  '64': ['271', '330'],
#  '64km': ['105'],
#  '65': ['312'],
#  '650': ['202', '209'],
#  '65000': ['060'],
#  '65cm': ['062'],
#  '66': ['103', '190', '191', '250'],
#  '6600': ['303'],
#  '67': ['023'],
#  '68': ['067', '275', '289'],
#  '6th': ['001', '068', '141'],
#  '70': ['015', '216', '256', '272'],
#  '70000': ['270'],
#  '700000': ['195'],
#  '700s': ['141'],
#  '701': ['201'],
#  '704': ['169', '201'],
#  '7090': ['129'],
#  ...}

# %% [markdown]
# Ahora traemos los datos de los queries y de los documentos ya procesada, esto se hace desde sus respectivas clases

# %%
from algorithms.binary_search.query_processor import QueryProcessor
from algorithms.binary_search.text_processor import TextProcessor

texts = TextProcessor()
queries = QueryProcessor()

text_df = texts.process_texts()
queries_df = queries.process_queries()
# Out:
# 2024-09-04 12:18:29,377 - INFO - QueryProcessor initialized
# 2024-09-04 12:18:29,377 - TextProcessor - INFO - Starting text processing pipeline
# 2024-09-04 12:18:29,377 - TextProcessor - INFO - Starting text processing pipeline
# 2024-09-04 12:18:29,377 - INFO - Starting text processing pipeline
# 2024-09-04 12:18:29,378 - TextProcessor - INFO - Reading files from directory: data/docs-raw-texts/
# 2024-09-04 12:18:29,378 - TextProcessor - INFO - Reading files from directory: data/docs-raw-texts/
# 2024-09-04 12:18:29,378 - INFO - Reading files from directory: data/docs-raw-texts/
# 2024-09-04 12:18:29,439 - TextProcessor - INFO - Finished reading files. Time taken: 0.06 seconds
# 2024-09-04 12:18:29,439 - TextProcessor - INFO - Finished reading files. Time taken: 0.06 seconds
# 2024-09-04 12:18:29,439 - INFO - Finished reading files. Time taken: 0.06 seconds
# 2024-09-04 12:18:29,440 - TextProcessor - INFO - Replacing titles in text and cleaning newlines
# 2024-09-04 12:18:29,440 - TextProcessor - INFO - Replacing titles in text and cleaning newlines
# 2024-09-04 12:18:29,440 - INFO - Replacing titles in text and cleaning newlines
# C:\Users\Rog\Desktop\Andes\10\Natural Language Processing\NLP\HW01\algorithms\binary_search\text_processor.py:82: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataFrame["text"][i] = dataFrame["text"][i].replace(dataFrame["title"][i] + ".", "")
# C:\Users\Rog\Desktop\Andes\10\Natural Language Processing\NLP\HW01\algorithms\binary_search\text_processor.py:83: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataFrame["text"][i] = dataFrame["text"][i].replace("\n", "")
# 2024-09-04 12:18:29,460 - TextProcessor - INFO - Finished replacing titles. Time taken: 0.02 seconds
# 2024-09-04 12:18:29,460 - TextProcessor - INFO - Finished replacing titles. Time taken: 0.02 seconds
# 2024-09-04 12:18:29,460 - INFO - Finished replacing titles. Time taken: 0.02 seconds
# 2024-09-04 12:18:29,462 - TextProcessor - INFO - Processing and normalizing text
# 2024-09-04 12:18:29,462 - TextProcessor - INFO - Processing and normalizing text
# 2024-09-04 12:18:29,462 - INFO - Processing and normalizing text
# 2024-09-04 12:18:31,243 - TextProcessor - INFO - Completed text processing pipeline. Total time taken: 1.86 seconds
# 2024-09-04 12:18:31,243 - TextProcessor - INFO - Completed text processing pipeline. Total time taken: 1.86 seconds
# 2024-09-04 12:18:31,243 - INFO - Completed text processing pipeline. Total time taken: 1.86 seconds
# 2024-09-04 12:18:31,251 - INFO - Read 35 queries
# 2024-09-04 12:18:31,259 - INFO - Processed all queries

# %% [markdown]
# En el procesamiento se esta haciendo los pasos de:
# * tokenizacion
# * lowercase
# * remover stop_words
# * Stemming

# %% [markdown]
# viendose los resultados como

# %%
text_df.head(5)
# Out:
#   identifier                                               text  \
# 0        001  william beaumont physiolog digest imag sourc n...
# 1        002  cover wonder adventur nil novemb 20 1858 swedi...
# 2        003  ferdinand mari vicomt de lessep 18051894 novem...
# 3        004  mickey mous star walk fame imag flickr user fr...
# 4        005  eugen paul wigner 19021995 novemb 17 1902 hung...
#
#                                            text_list
# 0  [william, beaumont, physiolog, digest, imag, s...
# 1  [cover, wonder, adventur, nil, novemb, 20, 185...
# 2  [ferdinand, mari, vicomt, de, lessep, 18051894...
# 3  [mickey, mous, star, walk, fame, imag, flickr,...
# 4  [eugen, paul, wigner, 19021995, novemb, 17, 19...

# %%
queries_df.head(5)
# Out:
#   identifier                             query  \
# 0        q01  Fabrication of music instruments
# 1        q02              famous German poetry
# 2        q03                       Romanticism
# 3        q04  University of Edinburgh research
# 4        q06               bridge construction
#
#                   processed_query                      query_list
# 0     [fabric, music, instrument]     [fabric, music, instrument]
# 1        [famous, german, poetri]        [famous, german, poetri]
# 2                      [romantic]                      [romantic]
# 3  [univers, edinburgh, research]  [univers, edinburgh, research]
# 4              [bridg, construct]              [bridg, construct]

# %% [markdown]
# ## Consultas BOOLEANAS

# %% [markdown]
# ### AND

# %% [markdown]
# Para el AND hicimos uso de los metodos de intersect dentro de binary_search.py donde hayamos, como dice su nombre, la interseccion  entre 2 listas como si fuera una busqueda de AND. Esto se realiza para todas las queries con documento iterando sobre sus terminos en el indice invertido. Este metodo lo podemos ver en funcionamiento desde la clase de search_engine.py donde finalmente hacemos el llamado para procesar los queries y arrojar los resultados

# %%
from algorithms.binary_search.search_engine import SearchEngine


query_processor = QueryProcessor()

search_engine = SearchEngine()
output_file = "results/BSII-AND-queries_result.txt"
search_engine.generate_results_file(queries_df, output_file)

with open(output_file, 'r') as f:
    print(f.read())
# Out:
# 2024-09-04 12:18:31,282 - INFO - QueryProcessor initialized
# 2024-09-04 12:18:31,299 - INFO - SearchEngine initialized
# 2024-09-04 12:18:31,302 - INFO - Results file generated: results/BSII-AND-queries_result.txt
# q01
# q02 d291,d293
# q03 d105,d147,d152,d283,d291,d318
# q04 d286
# q05 d026,d029,d069,d257,d297,d303,d329
# q06 d004,d034
# q07 d108,d110,d117,d205,d251
# q08 d198,d205,d223
# q09 d231
# q10 d250,d277
# q11
# q12
# q13 d132,d150,d176,d184,d229,d250,d277
# q14 d121,d271
# q15 d192,d194,d203,d210
# q16 d179
# q17
# q18
# q19 d129,d221,d240,d282
# q20 d020,d032,d167,d211
# q21
# q22
# q23 d136,d174
# q24 d037,d046,d294
# q25 d025,d031,d090,d139,d254
# q26
# q27 d257,d265
# q28 d169
# q29
# q30
# q31 d150,d174
# q32
# q33 d029,d185
# q34 d105
# q35 d094,d133

# %% [markdown]
# ### NOT
